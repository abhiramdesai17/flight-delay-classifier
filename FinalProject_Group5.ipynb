# %% [markdown]
# #Final Project --- Group 5

# %%
#Import all Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn import datasets
import matplotlib as mpl
from sklearn.metrics import confusion_matrix

from sklearn.metrics import precision_recall_fscore_support as score
# !pip install --upgrade openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
from google.colab import files
file = files.upload()  #upload file into google colab session
df19 = pd.read_csv("Jan_2019_ontime.csv") 
df19.head()
# Out:
#      <input type="file" id="files-b9806ec7-8dc9-441e-bd6e-369ab3f31c14" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9806ec7-8dc9-441e-bd6e-369ab3f31c14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-92af9f82120a> in <module>()
#       1 from google.colab import files
# ----> 2 file = files.upload()  #upload file into google colab session
#       3 df19 = pd.read_csv("Jan_2019_ontime.csv")
#       4 df19.head()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in _upload_files(multiple)
#     127     result = _output.eval_js(
#     128         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# --> 129             output_id=output_id))
#     130     if result['action'] != 'append':
#     131       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
df19
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              9E   N8688C               3280              11953
# 1              9E   N348PQ               3281              13487
# 2              9E   N8896A               3282              11433
# 3              9E   N8886A               3283              15249
# 4              9E   N8974C               3284              10397
# ...           ...      ...                ...                ...
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1195302    GNV  ...              1039707   ATL    601.0
# 1                     1348702    MSP  ...              1119302   CVG   1359.0
# 2                     1143302    DTW  ...              1119302   CVG   1215.0
# 3                     1524906    TLH  ...              1039707   ATL   1521.0
# 4                     1039707    ATL  ...              1177801   FSM   1847.0
# ...                       ...    ...  ...                  ...   ...      ...
# 583980                1201602    GUM  ...              1217305   HNL    749.0
# 583981                1201602    GUM  ...              1495503   SPN    717.0
# 583982                1495503    SPN  ...              1201602   GUM    857.0
# 583983                1495503    SPN  ...              1201602   GUM   1820.0
# 583984                1201602    GUM  ...              1495503   SPN   1636.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             0.0     0600-0659    722.0        0.0          0         0
# 1             0.0     1400-1459   1633.0        0.0          0         0
# 2             0.0     1200-1259   1329.0        0.0          0         0
# 3             0.0     1500-1559   1625.0        0.0          0         0
# 4             0.0     1900-1959   1940.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 583980        0.0     0700-0759   1832.0        0.0          0         0
# 583981        0.0     0700-0759    759.0        0.0          0         0
# 583982        0.0     0900-0959    933.0        0.0          0         0
# 583983        0.0     1800-1859   1854.0        0.0          0         0
# 583984        0.0     1600-1659   1719.0        0.0          0         0
#
#         DISTANCE
# 0            300
# 1            596
# 2            229
# 3            223
# 4            579
# ...          ...
# 583980      3801
# 583981       129
# 583982       129
# 583983       129
# 583984       129
#
# [583985 rows x 21 columns]

# %%
#create a copy
df_copy = df19.copy()
df_copy
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              9E   N8688C               3280              11953
# 1              9E   N348PQ               3281              13487
# 2              9E   N8896A               3282              11433
# 3              9E   N8886A               3283              15249
# 4              9E   N8974C               3284              10397
# ...           ...      ...                ...                ...
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1195302    GNV  ...              1039707   ATL    601.0
# 1                     1348702    MSP  ...              1119302   CVG   1359.0
# 2                     1143302    DTW  ...              1119302   CVG   1215.0
# 3                     1524906    TLH  ...              1039707   ATL   1521.0
# 4                     1039707    ATL  ...              1177801   FSM   1847.0
# ...                       ...    ...  ...                  ...   ...      ...
# 583980                1201602    GUM  ...              1217305   HNL    749.0
# 583981                1201602    GUM  ...              1495503   SPN    717.0
# 583982                1495503    SPN  ...              1201602   GUM    857.0
# 583983                1495503    SPN  ...              1201602   GUM   1820.0
# 583984                1201602    GUM  ...              1495503   SPN   1636.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             0.0     0600-0659    722.0        0.0          0         0
# 1             0.0     1400-1459   1633.0        0.0          0         0
# 2             0.0     1200-1259   1329.0        0.0          0         0
# 3             0.0     1500-1559   1625.0        0.0          0         0
# 4             0.0     1900-1959   1940.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 583980        0.0     0700-0759   1832.0        0.0          0         0
# 583981        0.0     0700-0759    759.0        0.0          0         0
# 583982        0.0     0900-0959    933.0        0.0          0         0
# 583983        0.0     1800-1859   1854.0        0.0          0         0
# 583984        0.0     1600-1659   1719.0        0.0          0         0
#
#         DISTANCE
# 0            300
# 1            596
# 2            229
# 3            223
# 4            579
# ...          ...
# 583980      3801
# 583981       129
# 583982       129
# 583983       129
# 583984       129
#
# [583985 rows x 21 columns]

# %%
df = df_copy

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0              9E   N8688C               3280              11953
# 1              9E   N348PQ               3281              13487
# 2              9E   N8896A               3282              11433
# 3              9E   N8886A               3283              15249
# 4              9E   N8974C               3284              10397
# ...           ...      ...                ...                ...
# 583980         UA   N776UA                200              12016
# 583981         UA   N36280                174              12016
# 583982         UA   N36280                117              14955
# 583983         UA   N39726                105              14955
# 583984         UA   N39726                104              12016
#
#         ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST_AIRPORT_SEQ_ID  DEST DEP_TIME  \
# 0                     1195302    GNV  ...              1039707   ATL    601.0
# 1                     1348702    MSP  ...              1119302   CVG   1359.0
# 2                     1143302    DTW  ...              1119302   CVG   1215.0
# 3                     1524906    TLH  ...              1039707   ATL   1521.0
# 4                     1039707    ATL  ...              1177801   FSM   1847.0
# ...                       ...    ...  ...                  ...   ...      ...
# 583980                1201602    GUM  ...              1217305   HNL    749.0
# 583981                1201602    GUM  ...              1495503   SPN    717.0
# 583982                1495503    SPN  ...              1201602   GUM    857.0
# 583983                1495503    SPN  ...              1201602   GUM   1820.0
# 583984                1201602    GUM  ...              1495503   SPN   1636.0
#
#         DEP_DEL15  DEP_TIME_BLK ARR_TIME  ARR_DEL15  CANCELLED  DIVERTED  \
# 0             0.0     0600-0659    722.0        0.0          0         0
# 1             0.0     1400-1459   1633.0        0.0          0         0
# 2             0.0     1200-1259   1329.0        0.0          0         0
# 3             0.0     1500-1559   1625.0        0.0          0         0
# 4             0.0     1900-1959   1940.0        0.0          0         0
# ...           ...           ...      ...        ...        ...       ...
# 583980        0.0     0700-0759   1832.0        0.0          0         0
# 583981        0.0     0700-0759    759.0        0.0          0         0
# 583982        0.0     0900-0959    933.0        0.0          0         0
# 583983        0.0     1800-1859   1854.0        0.0          0         0
# 583984        0.0     1600-1659   1719.0        0.0          0         0
#
#         DISTANCE
# 0            300
# 1            596
# 2            229
# 3            223
# 4            579
# ...          ...
# 583980      3801
# 583981       129
# 583982       129
# 583983       129
# 583984       129
#
# [583985 rows x 21 columns]

# %% [markdown]
# **Checking NULL values count**

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH                 0
# DAY_OF_WEEK                  0
# OP_UNIQUE_CARRIER            0
# OP_CARRIER_AIRLINE_ID        0
# OP_CARRIER                   0
# TAIL_NUM                  2543
# OP_CARRIER_FL_NUM            0
# ORIGIN_AIRPORT_ID            0
# ORIGIN_AIRPORT_SEQ_ID        0
# ORIGIN                       0
# DEST_AIRPORT_ID              0
# DEST_AIRPORT_SEQ_ID          0
# DEST                         0
# DEP_TIME                 16352
# DEP_DEL15                16355
# DEP_TIME_BLK                 0
# ARR_TIME                 17061
# ARR_DEL15                18022
# CANCELLED                    0
# DIVERTED                     0
# DISTANCE                     0
# dtype: int64

# %% [markdown]
# **Cleaning the data --- Removing records containing NULL values**

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# OP_UNIQUE_CARRIER        0
# OP_CARRIER_AIRLINE_ID    0
# OP_CARRIER               0
# TAIL_NUM                 0
# OP_CARRIER_FL_NUM        0
# ORIGIN_AIRPORT_ID        0
# ORIGIN_AIRPORT_SEQ_ID    0
# ORIGIN                   0
# DEST_AIRPORT_ID          0
# DEST_AIRPORT_SEQ_ID      0
# DEST                     0
# DEP_TIME                 0
# DEP_DEL15                0
# DEP_TIME_BLK             0
# ARR_TIME                 0
# ARR_DEL15                0
# CANCELLED                0
# DIVERTED                 0
# DISTANCE                 0
# dtype: int64

# %% [markdown]
# **DATA CLEANING - Dropping columns that are redundant**

# %%
# Dropping the redundant columns
df = df.drop(['OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID'], axis=1)

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  \
# 0             1            2                9E   N8688C               3280
# 1             1            2                9E   N348PQ               3281
# 2             1            2                9E   N8896A               3282
# 3             1            2                9E   N8886A               3283
# 4             1            2                9E   N8974C               3284
#
#   ORIGIN DEST  DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  \
# 0    GNV  ATL     601.0        0.0    0600-0659     722.0        0.0
# 1    MSP  CVG    1359.0        0.0    1400-1459    1633.0        0.0
# 2    DTW  CVG    1215.0        0.0    1200-1259    1329.0        0.0
# 3    TLH  ATL    1521.0        0.0    1500-1559    1625.0        0.0
# 4    ATL  FSM    1847.0        0.0    1900-1959    1940.0        0.0
#
#    CANCELLED  DIVERTED  DISTANCE
# 0          0         0       300
# 1          0         0       596
# 2          0         0       229
# 3          0         0       223
# 4          0         0       579

# %%
df = df.drop(['OP_CARRIER_FL_NUM'],axis=1)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM ORIGIN DEST  \
# 0                  1            2                9E   N8688C    GNV  ATL
# 1                  1            2                9E   N348PQ    MSP  CVG
# 2                  1            2                9E   N8896A    DTW  CVG
# 3                  1            2                9E   N8886A    TLH  ATL
# 4                  1            2                9E   N8974C    ATL  FSM
# ...              ...          ...               ...      ...    ...  ...
# 583980            31            4                UA   N776UA    GUM  HNL
# 583981            31            4                UA   N36280    GUM  SPN
# 583982            31            4                UA   N36280    SPN  GUM
# 583983            31            4                UA   N39726    SPN  GUM
# 583984            31            4                UA   N39726    GUM  SPN
#
#         DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  \
# 0          601.0        0.0    0600-0659     722.0        0.0          0
# 1         1359.0        0.0    1400-1459    1633.0        0.0          0
# 2         1215.0        0.0    1200-1259    1329.0        0.0          0
# 3         1521.0        0.0    1500-1559    1625.0        0.0          0
# 4         1847.0        0.0    1900-1959    1940.0        0.0          0
# ...          ...        ...          ...       ...        ...        ...
# 583980     749.0        0.0    0700-0759    1832.0        0.0          0
# 583981     717.0        0.0    0700-0759     759.0        0.0          0
# 583982     857.0        0.0    0900-0959     933.0        0.0          0
# 583983    1820.0        0.0    1800-1859    1854.0        0.0          0
# 583984    1636.0        0.0    1600-1659    1719.0        0.0          0
#
#         DIVERTED  DISTANCE
# 0              0       300
# 1              0       596
# 2              0       229
# 3              0       223
# 4              0       579
# ...          ...       ...
# 583980         0      3801
# 583981         0       129
# 583982         0       129
# 583983         0       129
# 583984         0       129
#
# [565963 rows x 14 columns]

# %% [markdown]
# **VISUALIZATIONS**

# %%
df.OP_UNIQUE_CARRIER.unique()
# Out:
# array(['9E', 'AA', 'MQ', 'G4', 'OH', 'B6', 'YV', 'EV', 'F9', 'YX', 'HA',
#        'NK', 'OO', 'WN', 'AS', 'UA', 'DL'], dtype=object)

# %%
# The data consist of 17 different airlines.
df.OP_UNIQUE_CARRIER.unique().shape
# Out:
# (17,)

# %%
# Top 10 airlines and the percentage of delayed flights (Departure) vs Total flights.

df_air=pd.DataFrame(df.groupby(["OP_UNIQUE_CARRIER","DEP_DEL15"])["ORIGIN"].count().unstack("DEP_DEL15").reset_index().values,columns=["Airline","Not_Delayed","Delayed"])
df_air["Percent Of Delayed"]=df_air.Delayed /( df_air.Delayed+ df_air.Not_Delayed)
df_air.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_air = df_air.head(10)
df_air
# Out:
#    Airline Not_Delayed Delayed Percent Of Delayed
# 14      WN       88769   18466           0.172201
# 4       DL       63990    9413           0.128237
# 1       AA       63361   11993           0.159155
# 12      OO       49190   12580           0.203659
# 13      UA       37768    8358           0.181199
# 16      YX       19779    4790           0.194961
# 11      OH       19068    3301            0.14757
# 9       MQ       19016    4694           0.197976
# 2       AS       17472    2732           0.135221
# 3       B6       17074    6321           0.270186

# %%
df_air.set_index("Airline").plot(kind='bar',stacked=True)
plt.show()

# %%
# Top 10 origin airports and the percentage of delayed flight (departure) vs total flights

df_org = pd.DataFrame(df.groupby(["ORIGIN","DEP_DEL15"])["ORIGIN"].count().unstack("DEP_DEL15").reset_index().values,columns=["Origin","Not_Delayed","Delayed"])
df_org["Percent Of Delayed"] = df_org.Delayed /( df_org.Delayed+ df_org.Not_Delayed)
df_org.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_org.head(10)
# Out:
#     Origin Not_Delayed Delayed Percent Of Delayed
# 19     ATL     26665.0  4118.0           0.133775
# 89     DFW     18677.0  4028.0           0.177406
# 238    ORD     16776.0  6560.0           0.281111
# 68     CLT     16101.0  2671.0           0.142286
# 88     DEN     14805.0  3415.0           0.187431
# 180    LAX     14643.0  3017.0           0.170838
# 251    PHX     12417.0  2123.0           0.146011
# 156    IAH     12381.0  2082.0           0.143954
# 178    LAS     10844.0  2201.0           0.168724
# 297    SFO     10111.0  2967.0            0.22687

# %%
df_org.head(10).set_index("Origin").plot(kind='bar',stacked=True)
plt.show()

# %%
# Top 10 departure time blocks and the percentage of delayed flights vs total flights

df_depblk = pd.DataFrame(df.groupby(["DEP_TIME_BLK","DEP_DEL15"])["ORIGIN"].count().unstack("DEP_DEL15").reset_index().values,columns=["DEP_TIME_BLK","Not_Delayed","Delayed"])
df_depblk["PercentOfDelayed"]=df_depblk.Delayed /( df_depblk.Delayed+ df_depblk.Not_Delayed)
df_depblk.sort_values(by="PercentOfDelayed",ascending=False,inplace=True)
df_depblk.head(10)
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed PercentOfDelayed
# 14    1900-1959       23195    7566         0.245961
# 13    1800-1859       25482    7894         0.236517
# 15    2000-2059       19431    5750         0.228347
# 16    2100-2159       13244    3889         0.226989
# 12    1700-1759       27955    8143          0.22558
# 11    1600-1659       26913    7342         0.214334
# 9     1400-1459       27507    7279         0.209251
# 10    1500-1559       27704    7240         0.207189
# 8     1300-1359       26108    6402         0.196924
# 17    2200-2259       10260    2336         0.185456

# %%
df_depblk.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_depblk = df_depblk.head(10)
df_depblk
# Out:
#    DEP_TIME_BLK Not_Delayed Delayed PercentOfDelayed
# 1     0600-0659       37791    2825         0.069554
# 2     0700-0759       33903    3366         0.090316
# 3     0800-0859       33814    4054         0.107056
# 6     1100-1159       29788    5983         0.167258
# 7     1200-1259       29357    6497         0.181207
# 5     1000-1059       29165    5465         0.157811
# 4     0900-0959       29121    4371         0.130509
# 12    1700-1759       27955    8143          0.22558
# 10    1500-1559       27704    7240         0.207189
# 9     1400-1459       27507    7279         0.209251

# %%
df_depblk.set_index("DEP_TIME_BLK").plot(kind='bar')

plt.show()

# %%
# This is a scatterplot between distance and delay. We plot this scatterplot to see if there is a relationship between the two. 
# From this scatterplot, we see that there is no clear relationship between the distance and the delay as a result of which we decide to drop the distance column.  

plt.scatter(df["DISTANCE"],df["DEP_DEL15"])
plt.show()

# %%
# Relationship between the day of the week and the delay in departure

df_dow=pd.DataFrame(df.groupby(["DAY_OF_WEEK","DEP_DEL15"])["ORIGIN"].count().unstack("DEP_DEL15").reset_index().values,columns=["DOW","Not_Delayed","Delayed"])
df_dow["PercentOfDelayed"]=df_dow.Delayed /( df_dow.Delayed+ df_dow.Not_Delayed)
df_dow.sort_values(by="Not_Delayed",ascending=False,inplace=True)
df_dow.head(10)
# Out:
#    DOW  Not_Delayed  Delayed  PercentOfDelayed
# 3    4        77444    19029          0.197247
# 2    3        76585    16758          0.179531
# 1    2        75431    14251          0.158906
# 4    5        65131    13523          0.171930
# 0    1        63320    13485          0.175575
# 6    7        58367    12493          0.176305
# 5    6        51380     8766          0.145745

# %%
df_dow.set_index("DOW").plot(kind='bar')
plt.show()

# %% [markdown]
# **Cancelled flights by Origin Airport**

# %%
#Bar chart - Delayed (departure time) flights by origin airport

plot3 = df.groupby('ORIGIN')['DEP_DEL15'].count().sort_values(ascending=False)
#cap to above 400
plot3 = plot3[plot3>400]
fig3 = px.bar(plot3,x=plot3.index,y=plot3.values,color_discrete_sequence=['#6ec8ba'],
             title="Delayed (departure time) flights by origin airport",labels={"ORIGIN":"Origin airport","y":"Count"})
fig3.layout.template = 'plotly_white'
fig3.update_xaxes(tickangle=45)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9361c55e-6869-44d4-9af3-eec59c6c7503" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9361c55e-6869-44d4-9af3-eec59c6c7503")) {                    Plotly.newPlot(                        "9361c55e-6869-44d4-9af3-eec59c6c7503",                        [{"alignmentgroup":"True","hovertemplate":"Origin airport=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#6ec8ba","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["ATL","ORD","DFW","CLT","DEN","LAX","PHX","IAH","LGA","SFO","LAS","MSP","MCO","DTW","DCA","BOS","EWR","JFK","SEA","SLC","PHL","FLL","MIA","BWI","SAN","TPA","DAL","BNA","MDW","STL","IAD","HOU","AUS","SJC","PDX","RDU","MSY","MCI","OAK","SMF","HNL","PIT","RSW","CLE","IND","CVG","CMH","SNA","SAT","JAX","PBI","MKE","SJU","BUR","BDL","OGG","OMA","MEM","ORF","RIC","OKC","TUS","SDF","BUF","ABQ","CHS","ONT","BOI","RNO","GRR","BHM","TUL","ELP","TYS","PVD","DSM","ANC","PSP","LGB","GSO","KOA","GSP","SAV","LIH","SYR","ROC","DAY","XNA","LIT","MSN","FAT","GEG","PNS","ALB","HPN","ASE","ICT","LEX","CHA","MAF","PWM","COS","SFB","HSV","SRQ","CID","BTV","SGF","JAN","CAE","BTR","AVL","BZN","MHT","MYR","FSD","FWA","PIE","ILM","LBB","SBA","EYW","CAK","SBN","SHV","VPS","TLH","ITO","MDT","ISP","EGE","AZA","CHO","ECP","CRP","MOB","PGD","AMA","LFT","JAC","MFE"],"xaxis":"x","y":[30783,23336,22705,18772,18220,17660,14540,14463,13350,13078,13045,11920,11837,11751,11178,10704,10244,10239,10120,9238,8877,8555,7813,7450,7372,6497,6100,6011,5620,5083,5082,4923,4879,4841,4704,4669,4539,4293,4120,3927,3921,3856,3702,3700,3683,3592,3555,3378,3213,2636,2395,2324,2290,2286,2277,2090,1952,1890,1873,1855,1820,1750,1743,1739,1691,1663,1633,1559,1526,1389,1386,1380,1326,1316,1293,1291,1290,1282,1202,1190,1190,1158,1134,1132,1041,1025,1018,1012,1012,980,956,916,891,884,848,821,778,739,721,717,700,690,690,690,661,661,654,651,648,617,603,594,573,572,567,551,549,541,539,535,532,531,523,515,511,488,482,478,473,467,455,451,443,441,439,430,419,416,415,405,402],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...

# %%
# Bar chart - Delayed (arrival time) flights by destination airport

plot4 = df.groupby('DEST')['ARR_DEL15'].count().sort_values(ascending=False)
#cap to above 400
plot4 = plot4[plot4>400]
fig4 = px.bar(plot4,x=plot4.index,y=plot4.values,color_discrete_sequence=['#1A7065'],
             title="Delayed (arrival time) flights by destination airport",labels={"DEST":"Destination airport","y":"Count"})
fig4.layout.template = 'plotly_white'
fig4.update_xaxes(tickangle=45)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dff9001d-4b14-4415-9b84-cd703e68a828" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dff9001d-4b14-4415-9b84-cd703e68a828")) {                    Plotly.newPlot(                        "dff9001d-4b14-4415-9b84-cd703e68a828",                        [{"alignmentgroup":"True","hovertemplate":"Destination airport=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1A7065","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["ATL","ORD","DFW","CLT","DEN","LAX","PHX","IAH","LGA","SFO","LAS","MSP","MCO","DTW","DCA","BOS","EWR","JFK","SEA","SLC","PHL","FLL","MIA","BWI","SAN","TPA","DAL","BNA","MDW","STL","IAD","HOU","AUS","SJC","PDX","RDU","MSY","MCI","OAK","SMF","HNL","PIT","CLE","RSW","IND","CVG","CMH","SNA","SAT","JAX","PBI","MKE","BUR","SJU","BDL","OGG","OMA","MEM","ORF","RIC","OKC","TUS","SDF","BUF","ABQ","CHS","ONT","BOI","RNO","GRR","BHM","TUL","ELP","TYS","PVD","DSM","ANC","PSP","LGB","KOA","GSO","GSP","SAV","LIH","SYR","ROC","DAY","XNA","LIT","MSN","FAT","GEG","ALB","PNS","HPN","ASE","ICT","LEX","CHA","MAF","PWM","COS","SFB","HSV","BTV","CID","SRQ","SGF","JAN","CAE","BTR","AVL","MHT","BZN","MYR","FSD","FWA","PIE","ILM","LBB","SBA","EYW","CAK","SBN","SHV","TLH","VPS","ITO","MDT","ISP","EGE","AZA","CHO","CRP","ECP","MOB","PGD","AMA","LFT","FAR"],"xaxis":"x","y":[30797,23262,22723,18781,18232,17655,14552,14427,13344,13063,13059,11949,11850,11718,11165,10733,10246,10245,10120,9281,8885,8560,7806,7451,7360,6486,6090,6024,5595,5086,5057,4917,4894,4821,4699,4675,4532,4300,4112,3933,3919,3857,3716,3705,3673,3592,3557,3381,3217,2649,2405,2328,2297,2282,2279,2087,1945,1894,1877,1867,1804,1756,1745,1735,1708,1659,1633,1558,1530,1395,1388,1383,1325,1318,1298,1298,1289,1277,1197,1192,1189,1163,1135,1128,1039,1031,1020,1015,1014,984,956,912,890,887,845,818,778,737,723,721,700,698,692,690,663,663,662,652,649,617,602,588,576,568,567,553,550,542,540,538,534,533,525,519,512,486,484,479,469,466,462,452,444,441,440,427,421,417,412,403],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...

# %%
# Donut chart - top 10 Airlines with most delayed flights (departure)

plot6 = df.groupby('OP_UNIQUE_CARRIER')['DEP_DEL15'].sum().sort_values().head(10)
fig6 = px.pie(names=plot6.index,values=list(map(int,plot6.values)),
              color_discrete_sequence =px.colors.qualitative.T10, hole=0.5, title='Airlines with most delayed flights (departure)')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6d68d12b-ebd0-44c4-b4e9-055904b0b6f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d68d12b-ebd0-44c4-b4e9-055904b0b6f6")) {                    Plotly.newPlot(                        "6d68d12b-ebd0-44c4-b4e9-055904b0b6f6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["HA","G4","NK","F9","EV","AS","YV","OH","9E","MQ"],"legendgroup":"","name":"","showlegend":true,"values":[585,1435,2167,2330,2509,2732,2902,3301,3729,4694],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...

# %%
# Pie Chart - Top 10 Airports with most delayed flights (departure)

plot6 = df.groupby('ORIGIN')['DEP_DEL15'].sum().sort_values().head(10)
fig6 = px.pie(names=plot6.index,values=list(map(int,plot6.values)),
              color_discrete_sequence =px.colors.qualitative.T10, hole=0.0, title='Airports with most delayed flights (departure)')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5f372114-a301-4083-b5fd-21ead23aaac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f372114-a301-4083-b5fd-21ead23aaac0")) {                    Plotly.newPlot(                        "5f372114-a301-4083-b5fd-21ead23aaac0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.0,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["PPG","ELM","SWO","LYH","GGG","LWS","EKO","CPR","BRW","ADK"],"legendgroup":"","name":"","showlegend":true,"values":[0,1,1,2,2,2,2,2,2,2],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth" ...

# %%
# Donut chart - Top 10 Airlines with most delayed flights (arrival)

plot6 = df.groupby('OP_UNIQUE_CARRIER')['ARR_DEL15'].sum().sort_values().head(10)
fig6 = px.pie(names=plot6.index,values=list(map(int,plot6.values)),
              color_discrete_sequence =px.colors.qualitative.T10, hole=0.5, title='Airlines with most delayed flights (arrival)')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3580083d-6a39-4506-bba6-2fefde2c1c9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3580083d-6a39-4506-bba6-2fefde2c1c9a")) {                    Plotly.newPlot(                        "3580083d-6a39-4506-bba6-2fefde2c1c9a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["HA","G4","F9","NK","EV","YV","OH","AS","9E","MQ"],"legendgroup":"","name":"","showlegend":true,"values":[851,1728,2362,2383,3022,3310,3475,3506,4013,5844],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...

# %%
# Pie Chart - Top 10 Airports with most delayed flights (arrival)

plot6 = df.groupby('DEST')['ARR_DEL15'].sum().sort_values().head(10)
fig6 = px.pie(names=plot6.index,values=list(map(int,plot6.values)),
              color_discrete_sequence =px.colors.qualitative.T10, hole=0.0, title='Airports with most delayed flights (arrival)')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="49fd0a33-c30f-43dd-b00a-bfa6ef367904" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49fd0a33-c30f-43dd-b00a-bfa6ef367904")) {                    Plotly.newPlot(                        "49fd0a33-c30f-43dd-b00a-bfa6ef367904",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.0,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["ELM","ADK","STC","PPG","SMX","BTM","OWB","LWS","CPR","LYH"],"legendgroup":"","name":"","showlegend":true,"values":[0,1,2,2,3,3,3,3,3,3],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth" ...

# %% [markdown]
# **Converting Categorical variables to Numerical values** --- Using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Here, we are using LabelEncoder() to convert our categorical variables into numerical variables so that we can standardize data 

le = LabelEncoder()
OP_UNIQUE_encoded = le.fit_transform(df['OP_UNIQUE_CARRIER'])
TAIL_NUM_encoded = le.fit_transform(df['TAIL_NUM'])
ORIGIN_encoded = le.fit_transform(df['ORIGIN'])
DEST_encoded = le.fit_transform(df['DEST'])

# %%
df['OP_UNIQUE_encoded'] = OP_UNIQUE_encoded
df['TAIL_NUM_encoded'] = TAIL_NUM_encoded
df['ORIGIN_encoded'] = ORIGIN_encoded
df['DEST_encoded'] = DEST_encoded

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM ORIGIN DEST  \
# 0                  1            2                9E   N8688C    GNV  ATL
# 1                  1            2                9E   N348PQ    MSP  CVG
# 2                  1            2                9E   N8896A    DTW  CVG
# 3                  1            2                9E   N8886A    TLH  ATL
# 4                  1            2                9E   N8974C    ATL  FSM
# ...              ...          ...               ...      ...    ...  ...
# 583980            31            4                UA   N776UA    GUM  HNL
# 583981            31            4                UA   N36280    GUM  SPN
# 583982            31            4                UA   N36280    SPN  GUM
# 583983            31            4                UA   N39726    SPN  GUM
# 583984            31            4                UA   N39726    GUM  SPN
#
#         DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  \
# 0          601.0        0.0    0600-0659     722.0        0.0          0
# 1         1359.0        0.0    1400-1459    1633.0        0.0          0
# 2         1215.0        0.0    1200-1259    1329.0        0.0          0
# 3         1521.0        0.0    1500-1559    1625.0        0.0          0
# 4         1847.0        0.0    1900-1959    1940.0        0.0          0
# ...          ...        ...          ...       ...        ...        ...
# 583980     749.0        0.0    0700-0759    1832.0        0.0          0
# 583981     717.0        0.0    0700-0759     759.0        0.0          0
# 583982     857.0        0.0    0900-0959     933.0        0.0          0
# 583983    1820.0        0.0    1800-1859    1854.0        0.0          0
# 583984    1636.0        0.0    1600-1659    1719.0        0.0          0
#
#         DIVERTED  DISTANCE  OP_UNIQUE_encoded  TAIL_NUM_encoded  \
# 0              0       300                  0              4316
# 1              0       596                  0              1396
# 2              0       229                  0              4472
# 3              0       223                  0              4468
# 4              0       579                  0              4529
# ...          ...       ...                ...               ...
# 583980         0      3801                 13              3426
# 583981         0       129                 13              1462
# 583982         0       129                 13              1462
# 583983         0       129                 13              1677
# 583984         0       129                 13              1677
#
#         ORIGIN_encoded  DEST_encoded
# 0                  128            19
# 1                  225            80
# 2                   95            80
# 3                  325            19
# 4                   19           120
# ...                ...           ...
# 583980             139           145
# 583981             139           312
# 583982             312           139
# 583983             312           139
# 583984             139           312
#
# [565963 rows x 18 columns]

# %%
df = df.drop(['OP_UNIQUE_CARRIER','TAIL_NUM','ORIGIN','DEST'],axis=1)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  \
# 0                  1            2     601.0        0.0    0600-0659     722.0
# 1                  1            2    1359.0        0.0    1400-1459    1633.0
# 2                  1            2    1215.0        0.0    1200-1259    1329.0
# 3                  1            2    1521.0        0.0    1500-1559    1625.0
# 4                  1            2    1847.0        0.0    1900-1959    1940.0
# ...              ...          ...       ...        ...          ...       ...
# 583980            31            4     749.0        0.0    0700-0759    1832.0
# 583981            31            4     717.0        0.0    0700-0759     759.0
# 583982            31            4     857.0        0.0    0900-0959     933.0
# 583983            31            4    1820.0        0.0    1800-1859    1854.0
# 583984            31            4    1636.0        0.0    1600-1659    1719.0
#
#         ARR_DEL15  CANCELLED  DIVERTED  DISTANCE  OP_UNIQUE_encoded  \
# 0             0.0          0         0       300                  0
# 1             0.0          0         0       596                  0
# 2             0.0          0         0       229                  0
# 3             0.0          0         0       223                  0
# 4             0.0          0         0       579                  0
# ...           ...        ...       ...       ...                ...
# 583980        0.0          0         0      3801                 13
# 583981        0.0          0         0       129                 13
# 583982        0.0          0         0       129                 13
# 583983        0.0          0         0       129                 13
# 583984        0.0          0         0       129                 13
#
#         TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded
# 0                   4316             128            19
# 1                   1396             225            80
# 2                   4472              95            80
# 3                   4468             325            19
# 4                   4529              19           120
# ...                  ...             ...           ...
# 583980              3426             139           145
# 583981              1462             139           312
# 583982              1462             312           139
# 583983              1677             312           139
# 583984              1677             139           312
#
# [565963 rows x 14 columns]

# %%
DEP_TIME_BLK_encoded = le.fit_transform(df['DEP_TIME_BLK'])

# %%
blocks = []
for hour in range(0,24):
    hour_part = ('%02d' %(hour))
    blocks.append(hour_part + '00-' + hour_part + '59')
blocks

def get_arrival_time_blk(arr_time):
    arr_hour = str('%04d' %(arr_time))[:2]
    arr_block = None
    for block in blocks:
        #print (block,arr_hour)
        if block.startswith(arr_hour):
            arr_block = block
            break
    if arr_block == None and str(arr_time) == '2400.0':
        arr_block = '0000-0059'
        #print('Cannot find block for #' + str(arr_time) + '#: set block to #' + arr_block + '#')
    return arr_block

df['ARR_TIME_BLK'] = df.ARR_TIME.apply(get_arrival_time_blk)
# drop the no more useful ARR_TIME
df.drop(['ARR_TIME'], inplace=True, axis=1)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_TIME  DEP_DEL15 DEP_TIME_BLK  \
# 0                  1            2     601.0        0.0    0600-0659
# 1                  1            2    1359.0        0.0    1400-1459
# 2                  1            2    1215.0        0.0    1200-1259
# 3                  1            2    1521.0        0.0    1500-1559
# 4                  1            2    1847.0        0.0    1900-1959
# ...              ...          ...       ...        ...          ...
# 583980            31            4     749.0        0.0    0700-0759
# 583981            31            4     717.0        0.0    0700-0759
# 583982            31            4     857.0        0.0    0900-0959
# 583983            31            4    1820.0        0.0    1800-1859
# 583984            31            4    1636.0        0.0    1600-1659
#
#         ARR_DEL15  CANCELLED  DIVERTED  DISTANCE  OP_UNIQUE_encoded  \
# 0             0.0          0         0       300                  0
# 1             0.0          0         0       596                  0
# 2             0.0          0         0       229                  0
# 3             0.0          0         0       223                  0
# 4             0.0          0         0       579                  0
# ...           ...        ...       ...       ...                ...
# 583980        0.0          0         0      3801                 13
# 583981        0.0          0         0       129                 13
# 583982        0.0          0         0       129                 13
# 583983        0.0          0         0       129                 13
# 583984        0.0          0         0       129                 13
#
#         TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded ARR_TIME_BLK
# 0                   4316             128            19    0700-0759
# 1                   1396             225            80    1600-1659
# 2                   4472              95            80    1300-1359
# 3                   4468             325            19    1600-1659
# 4                   4529              19           120    1900-1959
# ...                  ...             ...           ...          ...
# 583980              3426             139           145    1800-1859
# 583981              1462             139           312    0700-0759
# 583982              1462             312           139    0900-0959
# 583983              1677             312           139    1800-1859
# 583984              1677             139           312    1700-1759
#
# [565963 rows x 14 columns]

# %%
DEP_TIME_BLK_encoded = le.fit_transform(df['DEP_TIME_BLK'])
ARR_TIME_BLK_encoded = le.fit_transform(df['ARR_TIME_BLK'])

# %%
df['DEP_TIME_BLK_encoded'] = DEP_TIME_BLK_encoded
df['ARR_TIME_BLK_encoded'] = ARR_TIME_BLK_encoded

# %%
df = df.drop(['DEP_TIME_BLK','ARR_TIME_BLK','DEP_TIME'],axis=1)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  ARR_DEL15  CANCELLED  DIVERTED  \
# 0                  1            2        0.0        0.0          0         0
# 1                  1            2        0.0        0.0          0         0
# 2                  1            2        0.0        0.0          0         0
# 3                  1            2        0.0        0.0          0         0
# 4                  1            2        0.0        0.0          0         0
# ...              ...          ...        ...        ...        ...       ...
# 583980            31            4        0.0        0.0          0         0
# 583981            31            4        0.0        0.0          0         0
# 583982            31            4        0.0        0.0          0         0
# 583983            31            4        0.0        0.0          0         0
# 583984            31            4        0.0        0.0          0         0
#
#         DISTANCE  OP_UNIQUE_encoded  TAIL_NUM_encoded  ORIGIN_encoded  \
# 0            300                  0              4316             128
# 1            596                  0              1396             225
# 2            229                  0              4472              95
# 3            223                  0              4468             325
# 4            579                  0              4529              19
# ...          ...                ...               ...             ...
# 583980      3801                 13              3426             139
# 583981       129                 13              1462             139
# 583982       129                 13              1462             312
# 583983       129                 13              1677             312
# 583984       129                 13              1677             139
#
#         DEST_encoded  DEP_TIME_BLK_encoded  ARR_TIME_BLK_encoded
# 0                 19                     1                     7
# 1                 80                     9                    16
# 2                 80                     7                    13
# 3                 19                    10                    16
# 4                120                    14                    19
# ...              ...                   ...                   ...
# 583980           145                     2                    18
# 583981           312                     2                     7
# 583982           139                     4                     9
# 583983           139                    13                    18
# 583984           312                    11                    17
#
# [565963 rows x 13 columns]

# %%
#The concentration of delay and timely arrivals both on departure and on arrival?
f, (ax,ax1) = plt.subplots(1,2, figsize=(12,6))
dep = sns.countplot(df['DEP_DEL15'], ax=ax)
dep.set_title('Depatures')
dep.set_xlabel('Labels')
dep.set_ylabel('Freq')

arr = sns.countplot(df['ARR_DEL15'], ax=ax1)
arr.set_title('Arrivals')
arr.set_xlabel('Labels')
arr.set_ylabel('Freq')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'Freq')

# %% [markdown]
# **PLOTTING PAIRPLOT**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df,vars=['ORIGIN_encoded','DEST_encoded','ARR_DEL15'])

# %% [markdown]
# **Histogram for frequency distribution of variables**

# %%
df.hist(figsize= (15, 14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f79595a0d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f79599a8990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f79598cb810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f79596674d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f795962b9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7959b2fd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958d10a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958cd5090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7958cd5110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958c8a790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958c06350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958bbb950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7958b72f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958b38590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958aefb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7958ab21d0>]],
#       dtype=object)

# %% [markdown]
# **Splitting the data where y is the target variable 'ARR_DEL15'**

# %%
x = df.drop('ARR_DEL15', axis=1)
y = df['ARR_DEL15']

# %%
x
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  CANCELLED  DIVERTED  DISTANCE  \
# 0                  1            2        0.0          0         0       300
# 1                  1            2        0.0          0         0       596
# 2                  1            2        0.0          0         0       229
# 3                  1            2        0.0          0         0       223
# 4                  1            2        0.0          0         0       579
# ...              ...          ...        ...        ...       ...       ...
# 583980            31            4        0.0          0         0      3801
# 583981            31            4        0.0          0         0       129
# 583982            31            4        0.0          0         0       129
# 583983            31            4        0.0          0         0       129
# 583984            31            4        0.0          0         0       129
#
#         OP_UNIQUE_encoded  TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded  \
# 0                       0              4316             128            19
# 1                       0              1396             225            80
# 2                       0              4472              95            80
# 3                       0              4468             325            19
# 4                       0              4529              19           120
# ...                   ...               ...             ...           ...
# 583980                 13              3426             139           145
# 583981                 13              1462             139           312
# 583982                 13              1462             312           139
# 583983                 13              1677             312           139
# 583984                 13              1677             139           312
#
#         DEP_TIME_BLK_encoded  ARR_TIME_BLK_encoded
# 0                          1                     7
# 1                          9                    16
# 2                          7                    13
# 3                         10                    16
# 4                         14                    19
# ...                      ...                   ...
# 583980                     2                    18
# 583981                     2                     7
# 583982                     4                     9
# 583983                    13                    18
# 583984                    11                    17
#
# [565963 rows x 12 columns]

# %%
y = y.astype(int)
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 583980    0
# 583981    0
# 583982    0
# 583983    0
# 583984    0
# Name: ARR_DEL15, Length: 565963, dtype: int64

# %% [markdown]
# **Standardizing the data**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
x_standardized = scaler.fit_transform(x)

# %%
x_standardized
# Out:
# array([[-1.64972961, -0.95758013, -0.4584834 , ..., -1.58857327,
#         -1.46125706, -1.43966146],
#        [-1.64972961, -0.95758013, -0.4584834 , ..., -0.93556167,
#          0.20863973,  0.27937321],
#        [-1.64972961, -0.95758013, -0.4584834 , ..., -0.93556167,
#         -0.20883447, -0.29363835],
#        ...,
#        [ 1.69835414,  0.08431028, -0.4584834 , ..., -0.30396028,
#         -0.83504576, -1.05765376],
#        [ 1.69835414,  0.08431028, -0.4584834 , ..., -0.30396028,
#          1.04358813,  0.66138091],
#        [ 1.69835414,  0.08431028, -0.4584834 , ...,  1.54802343,
#          0.62611393,  0.47037706]])

# %%
x_standardized = pd.DataFrame(x_standardized, columns = x.columns)
x_standardized
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  CANCELLED  DIVERTED  DISTANCE  \
# 0          -1.649730     -0.95758  -0.458483        0.0       0.0 -0.848174
# 1          -1.649730     -0.95758  -0.458483        0.0       0.0 -0.348449
# 2          -1.649730     -0.95758  -0.458483        0.0       0.0 -0.968040
# 3          -1.649730     -0.95758  -0.458483        0.0       0.0 -0.978170
# 4          -1.649730     -0.95758  -0.458483        0.0       0.0 -0.377149
# ...              ...          ...        ...        ...       ...       ...
# 565958      1.698354      0.08431  -0.458483        0.0       0.0  5.062426
# 565959      1.698354      0.08431  -0.458483        0.0       0.0 -1.136866
# 565960      1.698354      0.08431  -0.458483        0.0       0.0 -1.136866
# 565961      1.698354      0.08431  -0.458483        0.0       0.0 -1.136866
# 565962      1.698354      0.08431  -0.458483        0.0       0.0 -1.136866
#
#         OP_UNIQUE_encoded  TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded  \
# 0               -1.589141          0.960173       -0.422122     -1.588573
# 1               -1.589141         -0.896243        0.616432     -0.935562
# 2               -1.589141          1.059351       -0.775444     -0.935562
# 3               -1.589141          1.056808        1.687106     -1.588573
# 4               -1.589141          1.095589       -1.589157     -0.507357
# ...                   ...               ...             ...           ...
# 565958           0.841210          0.394347       -0.304348     -0.239730
# 565959           0.841210         -0.854283       -0.304348      1.548023
# 565960           0.841210         -0.854283        1.547919     -0.303960
# 565961           0.841210         -0.717595        1.547919     -0.303960
# 565962           0.841210         -0.717595       -0.304348      1.548023
#
#         DEP_TIME_BLK_encoded  ARR_TIME_BLK_encoded
# 0                  -1.461257             -1.439661
# 1                   0.208640              0.279373
# 2                  -0.208834             -0.293638
# 3                   0.417377              0.279373
# 4                   1.252325              0.852385
# ...                      ...                   ...
# 565958             -1.252520              0.661381
# 565959             -1.252520             -1.439661
# 565960             -0.835046             -1.057654
# 565961              1.043588              0.661381
# 565962              0.626114              0.470377
#
# [565963 rows x 12 columns]

# %% [markdown]
# **Principal Component Analysis**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler  #Using PCA on standardized data.
X_scaled = StandardScaler().fit_transform(x_standardized)

# %%
pca_ss = PCA(n_components=2)
pca_ss.fit_transform(X_scaled)
a=pca_ss.explained_variance_ratio_  #calculates proportion variance.
print(a)
# Out:
# [0.16886656 0.12088948]

# %%
b=pca_ss.explained_variance_   #calculates explained variance.
print(b)
# Out:
# [1.68866859 1.20889695]

# %%
c = np.cumsum(pca_ss.explained_variance_ratio_)  #calculates cummulative proportion of variance
c
# Out:
# array([0.16886656, 0.28975604])

# %% [markdown]
# We find the proportion variance, explained variance and cumulative proportion variance using PCA.
# Running our Data Mining models without using PCA, we get accuracies of more than 90%. Thus, we can conclude that after cleaning our data, our models fit the dataset well, as a result of which we need not perform dimension reduction using PCA before running our Data Mining models.
# Hence, we do not use the principal component values for our models.

# %% [markdown]
# **FINDING CORRELATION**

# %%
from numpy import cov

# %%
x_corr = x_standardized.corr(method='pearson', min_periods=1)
x_corr
# Out:
#                       DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  CANCELLED  \
# DAY_OF_MONTH              1.000000    -0.021999   0.027762        NaN
# DAY_OF_WEEK              -0.021999     1.000000  -0.003089        NaN
# DEP_DEL15                 0.027762    -0.003089   1.000000        NaN
# CANCELLED                      NaN          NaN        NaN        NaN
# DIVERTED                       NaN          NaN        NaN        NaN
# DISTANCE                 -0.016014     0.017024   0.011393        NaN
# OP_UNIQUE_encoded        -0.009234     0.002350   0.015895        NaN
# TAIL_NUM_encoded          0.002330    -0.005131  -0.006845        NaN
# ORIGIN_encoded           -0.006729     0.007340   0.004213        NaN
# DEST_encoded             -0.006257     0.007054   0.012643        NaN
# DEP_TIME_BLK_encoded     -0.006699     0.005687   0.133099        NaN
# ARR_TIME_BLK_encoded      0.003526     0.005529   0.087369        NaN
#
#                       DIVERTED  DISTANCE  OP_UNIQUE_encoded  TAIL_NUM_encoded  \
# DAY_OF_MONTH               NaN -0.016014          -0.009234          0.002330
# DAY_OF_WEEK                NaN  0.017024           0.002350         -0.005131
# DEP_DEL15                  NaN  0.011393           0.015895         -0.006845
# CANCELLED                  NaN       NaN                NaN               NaN
# DIVERTED                   NaN       NaN                NaN               NaN
# DISTANCE                   NaN  1.000000          -0.162142         -0.058460
# OP_UNIQUE_encoded          NaN -0.162142           1.000000         -0.045167
# TAIL_NUM_encoded           NaN -0.058460          -0.045167          1.000000
# ORIGIN_encoded             NaN  0.096434           0.039251         -0.050118
# DEST_encoded               NaN  0.096058           0.039465         -0.050089
# DEP_TIME_BLK_encoded       NaN -0.018876          -0.000950          0.005108
# ARR_TIME_BLK_encoded       NaN  0.020652           0.014545         -0.000118
#
#                       ORIGIN_encoded  DEST_encoded  DEP_TIME_BLK_encoded  \
# DAY_OF_MONTH               -0.006729     -0.006257             -0.006699
# DAY_OF_WEEK                 0.007340      0.007054              0.005687
# DEP_DEL15                   0.004213      0.012643              0.133099
# CANCELLED                        NaN           NaN                   NaN
# DIVERTED                         NaN           NaN                   NaN
# DISTANCE                    0.096434      0.096058             -0.018876
# OP_UNIQUE_encoded           0.039251      0.039465             -0.000950
# TAIL_NUM_encoded           -0.050118     -0.050089              0.005108
# ORIGIN_encoded              1.000000      0.015567             -0.033811
# DEST_encoded                0.015567      1.000000              0.026073
# DEP_TIME_BLK_encoded       -0.033811      0.026073              1.000000
# ARR_TIME_BLK_encoded       -0.004534      0.021171              0.650099
#
#                       ARR_TIME_BLK_encoded
# DAY_OF_MONTH                      0.003526
# DAY_OF_WEEK                       0.005529
# DEP_DEL15                         0.087369
# CANCELLED                              NaN
# DIVERTED                               NaN
# DISTANCE                          0.020652
# OP_UNIQUE_encoded                 0.014545
# TAIL_NUM_encoded                 -0.000118
# ORIGIN_encoded                   -0.004534
# DEST_encoded                      0.021171
# DEP_TIME_BLK_encoded              0.650099
# ARR_TIME_BLK_encoded              1.000000

# %% [markdown]
# **Since correlation values between the variables "CANCELLED" and "DIVERTED" ara all NaN, we drop the two columns from our dataframe.**

# %%
x_standardized = x_standardized.drop(['CANCELLED', 'DIVERTED'], axis=1)

# %%
x_corr = x_standardized.corr(method='pearson', min_periods=1)

# %%
heatmap = sns.heatmap(x_corr,annot=True,cmap = 'coolwarm')#plot the annoted heatmap using seaborn library
sns.set(rc = {'figure.figsize':(20,10)})
heatmap.set_title('Correlation Heatmap',fontdict={'fontsize':18}, pad=22)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# **SPLITTING DATA INTO TRAINING AND VALIDATION SETS**

# %%
# Importing necessary libraries for splitting the dataset

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# %%
# Splitting the data into training and validation sets using the x_standardized and y datasets

x_train, x_test, y_train, y_test= train_test_split(x_standardized,y,  test_size=0.2, random_state=0)

# %%
x_train
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  DISTANCE  OP_UNIQUE_encoded  \
# 370887      0.582326    -1.478525   2.181104 -1.241538           0.654260
# 353555      0.470723     1.647146  -0.458483 -0.954534          -1.402191
# 480397      1.251943     1.647146  -0.458483  0.450098           0.841210
# 232467     -0.310496     1.647146  -0.458483  0.418021           1.028160
# 187100     -0.645304     0.084310  -0.458483 -0.402473           0.467310
# ...              ...          ...        ...       ...                ...
# 359783      0.470723     1.647146  -0.458483  1.287476           1.028160
# 152315     -0.756907    -0.436635  -0.458483 -0.618570           1.028160
# 117952     -0.980113    -1.478525  -0.458483 -0.414291           0.654260
# 435829      0.917135     0.084310  -0.458483  0.774244           1.402060
# 305711      0.135915     0.084310  -0.458483 -0.679348           0.654260
#
#         TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded  DEP_TIME_BLK_encoded  \
# 370887          1.133099        0.755620      0.488218              1.461062
# 353555          1.500568        0.884101      1.066294              1.043588
# 480397         -0.487450       -0.936046     -0.849921              0.626114
# 232467         -1.374970        1.258837      1.366037              0.834851
# 187100         -0.231239       -1.064526     -0.207614              1.461062
# ...                  ...             ...           ...                   ...
# 359783         -1.083156        1.472972     -1.224600             -1.252520
# 152315          0.466824        0.487951      0.359756             -0.626309
# 117952          1.426820        0.991168     -0.849921             -0.626309
# 435829         -1.729723        0.884101      0.713025             -1.043783
# 305711         -1.424559        0.134629      1.601549              0.208640
#
#         ARR_TIME_BLK_encoded
# 370887              1.616400
# 353555              1.043389
# 480397              0.470377
# 232467              1.043389
# 187100              1.425396
# ...                      ...
# 359783             -1.057654
# 152315             -0.675646
# 117952             -0.675646
# 435829             -0.866650
# 305711              0.279373
#
# [452770 rows x 10 columns]

# %%
x_test
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  DEP_DEL15  DISTANCE  OP_UNIQUE_encoded  \
# 234668     -0.310496     1.647146  -0.458483 -0.090145           0.654260
# 189496     -0.645304     0.084310  -0.458483 -0.669218           1.402060
# 16925      -1.649730    -0.957580  -0.458483  0.242442          -0.841340
# 100178     -1.091716     1.647146  -0.458483 -1.201020           0.467310
# 142933     -0.868510    -0.957580  -0.458483 -0.914016          -1.215241
# ...              ...          ...        ...       ...                ...
# 404807      0.805532    -0.436635  -0.458483 -0.063133           0.093410
# 421717      0.805532    -0.436635  -0.458483 -0.351825          -0.841340
# 116373     -0.980113    -1.478525  -0.458483 -0.409226          -0.280490
# 138271     -0.868510    -0.957580  -0.458483 -1.212838           0.654260
# 550554      1.698354     0.084310  -0.458483 -0.542599           0.467310
#
#         TAIL_NUM_encoded  ORIGIN_encoded  DEST_encoded  DEP_TIME_BLK_encoded  \
# 234668         -1.497671       -1.364315      1.258986             -0.626309
# 189496         -1.620373       -0.861098      0.466808              0.208640
# 16925          -0.857462       -1.353608     -1.588573             -0.000097
# 100178         -0.339318       -1.064526     -1.556458             -0.417572
# 142933         -0.397172       -1.631984     -0.603703              1.461062
# ...                  ...             ...           ...                   ...
# 404807          0.770717       -1.375022      0.027898             -1.043783
# 421717          0.824756       -0.775444     -1.588573              1.043588
# 116373         -1.754518        1.751347      1.076999             -0.000097
# 138271          1.350529        1.301664      0.755845             -0.417572
# 550554         -0.335504       -1.792585     -1.064023             -0.417572
#
#         ARR_TIME_BLK_encoded
# 234668             -0.675646
# 189496              0.279373
# 16925               0.279373
# 100178             -0.484642
# 142933              1.043389
# ...                      ...
# 404807             -0.675646
# 421717              1.043389
# 116373              0.088369
# 138271             -0.675646
# 550554             -0.293638
#
# [113193 rows x 10 columns]

# %%
y_train
# Out:
# 378797    1
# 360202    0
# 491556    0
# 235516    0
# 189007    0
#          ..
# 367149    0
# 153895    0
# 119159    0
# 446490    0
# 310039    0
# Name: ARR_DEL15, Length: 452770, dtype: int64

# %%
y_test
# Out:
# 237807    0
# 191475    0
# 17067     0
# 101090    0
# 144421    0
#          ..
# 414545    0
# 432034    1
# 117565    0
# 139708    0
# 567041    0
# Name: ARR_DEL15, Length: 113193, dtype: int64

# %% [markdown]
# **MODEL 1 - DECISION TREE**

# %%
# !pip install pydotplus
# !pip install six
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (1.15.0)

# %%
# Importing Necessary libraries for Decision Tree Classifier 

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn import tree
#from sklearn.externals.six import StringIO  
from six import StringIO
import pydotplus
from IPython.display import Image 
dot_data = StringIO()
from sklearn import tree
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse , r2_score
from math import sqrt
from sklearn.metrics import accuracy_score 
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report , recall_score ,  precision_score
from sklearn.metrics import classification_report


# !pip install --upgrade scikit-learn==0.20.3
# !pip install --upgrade scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.20.3
#   Using cached scikit_learn-0.20.3-cp37-cp37m-manylinux1_x86_64.whl (5.4 MB)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.20.3) (1.4.1)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.20.3) (1.21.6)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.20.3 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.20.3 which is incompatible.
# Successfully installed scikit-learn-0.20.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.20.3)
# Collecting scikit-learn
#   Using cached scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.21.6)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.20.3
#     Uninstalling scikit-learn-0.20.3:
#       Successfully uninstalled scikit-learn-0.20.3
# Successfully installed scikit-learn-1.0.2

# %%
# Fitting the Training Dataset on the Decision Tree Classifier

clf = DecisionTreeClassifier(random_state = 0)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
# Plotting the decision tree with depth = 6

tree.export_graphviz(clf, max_depth = 6, feature_names=x_test.columns, out_file= dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
graph.write_png('tree.png')
# Out:
# True

# %%
graph

# %%
# Printing the image of the decision tree with depth=6

Image(graph.create_png())

# %%
y_pred_dt = clf.predict(x_test)

# %%
# The Decision Tree gives us an accuracy of 87.7 %

accuracy_dt = accuracy_score(y_test,y_pred_dt)
accuracy_dt
# Out:
# 0.8770065286722677

# %%
# Confusion Matrix of Decision Tree 

class_names=['Delay-False','Delay-true']
disp = plot_confusion_matrix(clf, x_test, y_test,display_labels=class_names, values_format='d',cmap='Blues')
precision = precision_score(y_test, clf.predict(x_test), average='binary')
recall = recall_score(y_test, clf.predict(x_test), average='binary')
print('Avg Precision:' +  str(precision))
print('Avg Recall:' + str(recall))
    
disp.ax_.set_title(clf)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning:
#
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Avg Precision:0.6629208265614116
# Avg Recall:0.6817899613162042

# %%
#Classification Report of Decision Tree Model

print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     92254
#            1       0.66      0.68      0.67     20939
#
#     accuracy                           0.88    113193
#    macro avg       0.80      0.80      0.80    113193
# weighted avg       0.88      0.88      0.88    113193

# %%
# Here, we are using the confusion_matrix function to generate a 2x2 confusion matrix so that we can use the TP, FP, TN and FN values to find the specificity.

confusion_mat_dt = confusion_matrix(y_test,y_pred_dt)
specificity_dt = confusion_mat_dt[1][1]/(confusion_mat_dt[1][0]+confusion_mat_dt[1][1])

# %%
y_test.shape
# Out:
# (113193,)

# %%
# Storing the "macro" values of precision, recall and f1 score of the Decision Tree

precision_dt,recall_dt,fscore_dt,support_dt=score(y_test,y_pred_dt,average='macro')

# %%
print(precision_dt,recall_dt,fscore_dt)
# Out:
# 0.7951133404665488 0.801552513122819 0.7982618797749386

# %%
# This is a dataframe of the Precision, Recall and F1 score from the Decision Tree that we have obtained above.

data =[['Decision Tree',accuracy_dt, 1-accuracy_dt, precision_dt,recall_dt, specificity_dt,fscore_dt]]
df_dt=pd.DataFrame(data,columns=['Model Name','Accuracy','Error','Precision (PPV)','Sensitivity / Recall','Specificity','F1 Score'])
df_dt
# Out:
#       Model Name  Accuracy     Error  Precision (PPV)  Sensitivity / Recall  \
# 0  Decision Tree  0.877007  0.122993         0.795113              0.801553
#
#    Specificity  F1 Score
# 0      0.68179  0.798262

# %% [markdown]
# **MODEL 2 - NAIVE BAYES**

# %%
# Importing the library for Naive Bayes model

from sklearn.naive_bayes import GaussianNB

# %%
# Fitting the Training Dataset on the Naive Bayes Model

GN_nb = GaussianNB()
model_naive = GN_nb.fit(x_train, y_train)

# %%
# Computing y_pred values in order to find accuracy of the model

y_pred_naive = model_naive.predict(x_test)

# %%
# The Naive Bayes model gives us an accuracy of 91.75 %

accuracy_naive = accuracy_score(y_test,y_pred_naive)
accuracy_naive
# Out:
# 0.9174948980944051

# %%
# Printing the Confusion Matrix of the Naive Bayes Model

class_names=['Delay-False','Delay-true']
disp = plot_confusion_matrix(model_naive, x_test, y_test,display_labels=class_names, values_format='d',cmap='Greens')
precision = precision_score(y_test, model_naive.predict(x_test), average='binary')
recall = recall_score(y_test,model_naive.predict(x_test), average='binary')
print('Avg Precision:' +  str(precision))
print('Avg Recall:' + str(recall))
    
disp.ax_.set_title(model_naive)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning:
#
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Avg Precision:0.7961903789194158
# Avg Recall:0.7445914322555997

# %%
# Here, we are using the confusion_matrix function to generate a 2x2 confusion matrix so that we can use the TP, FP, TN and FN values to find the specificity.

confusion_mat_naive = confusion_matrix(y_test,y_pred_naive)
specificity_naive = confusion_mat_naive[1][1]/(confusion_mat_naive[1][0]+confusion_mat_naive[1][1])

# %%
# Classification Report of Naive Bayes Model

print(classification_report(y_test, y_pred_naive))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     92254
#            1       0.80      0.74      0.77     20939
#
#     accuracy                           0.92    113193
#    macro avg       0.87      0.85      0.86    113193
# weighted avg       0.92      0.92      0.92    113193

# %%
# Storing the "macro" values of precision, recall and f1 score of the Naive Bayes model

precision_naive ,recall_naive,fscore_naive, support_naive=score(y_test,y_pred_naive,average='macro')

# %%
# This is a dataframe of the Precision, Recall and F1 score from the classification report that we have obtained above.

data =[['Naive Bayes Model',accuracy_naive, 1-accuracy_naive, precision_naive,recall_naive, specificity_naive,fscore_naive]]
df_naive=pd.DataFrame(data,columns=['Model Name','Accuracy','Error','Precision (PPV)','Sensitivity / Recall','Specificity','F1 Score'])
df_naive
# Out:
#           Model Name  Accuracy     Error  Precision (PPV)  \
# 0  Naive Bayes Model  0.917495  0.082505          0.86953
#
#    Sensitivity / Recall  Specificity  F1 Score
# 0              0.850665     0.744591   0.85964

# %% [markdown]
# **MODEL 3 - Multi-layer Perceptron (MLP) Classifier**

# %%
# Importing libraries necessary for MLP Classifier

from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

# %%
# Finding cross validation scores of the dataset

Model3 =MLPClassifier()
cv3= cross_val_score(Model3,x_train,y_train,cv=2)

# %%
cv3
# Out:
# array([0.91853701, 0.91904941])

# %%
# Fitting the Training Dataset on the MLP Classifier

model_mlp = Model3.fit(x_train, y_train)

# %%
# Computing y_pred values in order to find accuracy of the model

y_pred_mlp = model_mlp.predict(x_test)

# %%
# The Naive Bayes model gives us an accuracy of 91.91% , which is the best accuracy we obtain amongst all our models.
# This makes the MLP model the best model for our dataset

accuracy_mlp = accuracy_score(y_test,y_pred_mlp)
accuracy_mlp
# Out:
# 0.9192352884012263

# %%
# Printing the Confusion Matrix of the MLP Classifier

class_names=['Delay-False','Delay-true']
disp = plot_confusion_matrix(model_mlp, x_test, y_test,display_labels=class_names, values_format='d',cmap='Blues')
precision = precision_score(y_test, model_mlp.predict(x_test), average='binary')
recall = recall_score(y_test, model_mlp.predict(x_test), average='binary')
print('Avg Precision:' +  str(precision))
print('Avg Recall:' + str(recall))
    
disp.ax_.set_title(model_mlp)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning:
#
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Avg Precision:0.8253985767087769
# Avg Recall:0.7145517933043602

# %%
# Here, we are using the confusion_matrix function to generate a 2x2 confusion matrix so that we can use the TP, FP, TN and FN values to find the specificity.

confusion_mat_mlp = confusion_matrix(y_test,y_pred_mlp)
specificity_mlp = confusion_mat_mlp[1][1]/(confusion_mat_mlp[1][0]+confusion_mat_mlp[1][1])

# %%
# Classification report of the MLP Classifier

print(classification_report(y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     92254
#            1       0.83      0.71      0.77     20939
#
#     accuracy                           0.92    113193
#    macro avg       0.88      0.84      0.86    113193
# weighted avg       0.92      0.92      0.92    113193

# %%
# Storing the "macro" values of precision, recall and f1 score of the MLP Classifier

precision_mlp,recall_mlp,fscore_mlp,support_mlp = score(y_test,y_pred_mlp,average='macro')

# %%
# This is a dataframe of the Precision, Recall and F1 score from the Classification Report that we have obtained above.

data =[['MLP Classifier',accuracy_mlp, 1-accuracy_mlp, precision_mlp,recall_mlp, specificity_mlp,fscore_mlp]]
df_mlp=pd.DataFrame(data,columns=['Model Name','Accuracy','Error','Precision (PPV)','Sensitivity / Recall','Specificity','F1 Score'])
df_mlp
# Out:
#        Model Name  Accuracy     Error  Precision (PPV)  Sensitivity / Recall  \
# 0  MLP Classifier  0.919235  0.080765         0.881263              0.840122
#
#    Specificity  F1 Score
# 0     0.714552  0.858591

# %% [markdown]
# **MODEL 4 - Logistic Regression Model**

# %%
# Load the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import confusion_matrix, accuracy_score 
# !pip install --upgrade openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
logistic_model = LogisticRegression() #making a logistic regression model
logistic_model.fit(x_train, y_train) #training the model
y_pred_log = logistic_model.predict(x_test) #model uses the learnt parameters from training data to predict the labels of tets data.
accuracy_log = accuracy_score(y_test,y_pred_log) #finds the accuracy of the model using the test data and the predicted data obtained in the above step
confusion_mat = confusion_matrix(y_test,y_pred_log) #creates a confusion matrix

# %%
# The Naive Bayes model gives us an accuracy of 91.74 %

print("Accuracy is",accuracy_log)
# Out:
# Accuracy is 0.9174948980944051

# %%
# Printing the Confusion Matrix of the Logistic Regression Model

print("Confusion Matrix\n",confusion_mat)
# Out:
# Confusion Matrix
#  [[88263  3991]
#  [ 5348 15591]]

# %%
# Here, we use the FP, TN and FN values to find the specificity.

specificity_log = confusion_mat[1][1]/(confusion_mat[1][0]+confusion_mat[1][1])

# %%
# Printing the Confusion Matrix of the Logistic Regression Model

class_names=['Delay-False','Delay-true']
disp = plot_confusion_matrix(logistic_model, x_test, y_test,display_labels=class_names, values_format='d',cmap='Reds')
precision = precision_score(y_test, logistic_model.predict(x_test), average='binary')
recall = recall_score(y_test,logistic_model.predict(x_test), average='binary')
print('Avg Precision:' +  str(precision))
print('Avg Recall:' + str(recall))
    
disp.ax_.set_title(logistic_model)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning:
#
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Avg Precision:0.7961903789194158
# Avg Recall:0.7445914322555997

# %%
# Classification report of the Logistic Regression Model

print(classification_report(y_test, y_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     92254
#            1       0.80      0.74      0.77     20939
#
#     accuracy                           0.92    113193
#    macro avg       0.87      0.85      0.86    113193
# weighted avg       0.92      0.92      0.92    113193

# %%
# Storing the "macro" values of precision, recall and f1 score of the Logistic Regression Model

precision_log,recall_log,fscore_log,support_log=score(y_test,y_pred_log,average='macro')

# %%
# This is a dataframe of the Precision, Recall and F1 score from the Classification Report that we have obtained above.

data =[['Logistic Regression Model',accuracy_log, 1-accuracy_log, precision_log,recall_log, specificity_log,fscore_log]]
df_dt=pd.DataFrame(data,columns=['Model Name','Accuracy','Error','Precision (PPV)','Sensitivity / Recall','Specificity','F1 Score'])
df_dt
# Out:
#                   Model Name  Accuracy     Error  Precision (PPV)  \
# 0  Logistic Regression Model  0.917495  0.082505          0.86953
#
#    Sensitivity / Recall  Specificity  F1 Score
# 0              0.850665     0.744591   0.85964

# %% [markdown]
# **Model 5 - Random Forest Classifier**

# %%
# Importing libraries required for Random Forest Classifier

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import math
import pandas_datareader.data as web
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fitting the Training Dataset on the Random Forest Classifier

rfc = RandomForestClassifier(n_estimators=20)
rfc.fit(x_train,y_train)

Y_train_pred = rfc.predict(x_train)
Y_test_pred = rfc.predict(x_test)     # Computing y_pred values in order to find accuracy of the model

accuracy_train_forest = accuracy_score(y_train,Y_train_pred)
accuracy_test_forest = accuracy_score(y_test,Y_test_pred)

print('ACCURACY train: %.4f, test: %.4f' %(accuracy_score(y_train,Y_train_pred), accuracy_score(y_test,Y_test_pred)))   

# The Random Forest model gives us an accuracy of 91.86 % which is the second highest accuracy, which makes the Random Forest Classifier the second-best model to train our dataset.
# Out:
# ACCURACY train: 0.9964, test: 0.9190

# %%
# Printing the Confusion Matrix of the Random Forest Classifier

class_names=['Delay-False','Delay-true']
disp = plot_confusion_matrix(rfc, x_test, y_test,display_labels=class_names, values_format='d',cmap='Oranges')
precision = precision_score(y_test, rfc.predict(x_test), average='binary')
recall = recall_score(y_test,rfc.predict(x_test), average='binary')
print('Avg Precision:' +  str(precision))
print('Avg Recall:' + str(recall))
    
disp.ax_.set_title(rfc)
plt.show()
# Out:
# Avg Precision:0.8216295972457511
# Avg Recall:0.7180381107025169

# %%
# Here, we are using the confusion_matrix function to generate a 2x2 confusion matrix so that we can use the TP, FP, TN and FN values to find the specificity.

confusion_mat_rf = confusion_matrix(y_test,Y_test_pred)
specificity_rf = confusion_mat_rf[1][1]/(confusion_mat_rf[1][0]+confusion_mat_rf[1][1])

# %%
# Classification report of the Random Forest Classifier

print(classification_report(y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     92254
#            1       0.82      0.72      0.77     20939
#
#     accuracy                           0.92    113193
#    macro avg       0.88      0.84      0.86    113193
# weighted avg       0.92      0.92      0.92    113193

# %%
# Storing the "macro" values of precision, recall and f1 score of the Random Forest classifier

precision_rf,recall_rf,fscore_rf,support_rf=score(y_test,Y_test_pred,average='macro')

# %%
# This is a dataframe of the Precision, Recall and F1 score from the Classification Report that we have obtained above.

data =[['Random forest Classifier',accuracy_test_forest, 1-accuracy_test_forest, precision_rf,recall_rf, specificity_rf,fscore_rf]]
df_rf=pd.DataFrame(data,columns=['Model Name','Accuracy','Error','Precision (PPV)','Sensitivity / Recall','Specificity','F1 Score'])
df_rf
# Out:
#                  Model Name  Accuracy     Error  Precision (PPV)  \
# 0  Random forest Classifier  0.919006  0.080994         0.879706
#
#    Sensitivity / Recall  Specificity  F1 Score
# 0              0.841329     0.718038   0.85868

# %% [markdown]
# **Evaluating Performance**

# %% [markdown]
# This is a dataframe of the model names and their respective computed accuracies.

# %%
data =[['Decision Tree', accuracy_dt], ['Naive Bayes', accuracy_naive], ['MLP Classifier', accuracy_mlp], ['Logistic Regression', accuracy_log], ['Random Forest Classifier', accuracy_test_forest]]
df1=pd.DataFrame(data,columns=['Model Name','Accuracies'])
df1
# Out:
#                  Model Name  Accuracies
# 0             Decision Tree    0.877007
# 1               Naive Bayes    0.917495
# 2            MLP Classifier    0.919235
# 3       Logistic Regression    0.917495
# 4  Random Forest Classifier    0.919006

# %% [markdown]
# **From the above dataframe, we observe that the best fitting model for our dataset is the MLP Classifier with an accuracy of 91.91 % and the second best model is the Random Forest Classifier with an accuracy of 91.86 %.**

# %% [markdown]
# **We also observe that the Decision Tree model has the lowest accuracy of 87.7 %.**

# %%
# This is a bar chart plotted to compare the accuracies of all five models.
# The best fitting model for our dataset is the MLP Classifier with an accuracy of 91.91 % and the second best model is the Random Forest Classifier with an accuracy of 91.86 %.
# We also observe that the Decision Tree model has the lowest accuracy of 87.7 %.

ax=df1.plot.bar(x='Model Name',y='Accuracies', rot=0)

# %%
# This is a dataframe of the models with their corresponding Precision, Recall and F1 score that we compute from their respective classification reports.

data =[['Decision Tree',precision_dt,recall_dt,fscore_dt], ['Naive Bayes',precision_naive,recall_naive,fscore_naive], ['MLP Classifier',precision_mlp,recall_mlp,fscore_mlp], ['Logistic Regression',precision_log,recall_log,fscore_log], ['Random Forest Classifier', precision_rf,recall_rf,fscore_rf]]
df2=pd.DataFrame(data,columns=['Model Name','Precision','Recall','F1 Score'])
df2
# Out:
#                  Model Name  Precision    Recall  F1 Score
# 0             Decision Tree   0.795113  0.801553  0.798262
# 1               Naive Bayes   0.869530  0.850665  0.859640
# 2            MLP Classifier   0.881263  0.840122  0.858591
# 3       Logistic Regression   0.869530  0.850665  0.859640
# 4  Random Forest Classifier   0.879706  0.841329  0.858680

# %% [markdown]
# We observe that the MLP Classifier, the Naive Bayes model, Logistic Regression Model and Random Forest Classifier have almost similar values, while the decision tree has comparitively lower values of the three parameters.
#
# Since the MLP Classifier has the highest accuracy along with good scores of Precision, Recall and also the hightst F1 score amongst all models, it is the best fit for our dataset.

# %%
# Grouped bar chart of the five models and their precision, recall and F1 scores

ax=df2.plot.bar(x='Model Name',rot=0)

# %% [markdown]
# **Therefore, we conclude that the Multi- Layer Perceptron (MLP) Classifier model is the best fitting classification model for our dataset.**
